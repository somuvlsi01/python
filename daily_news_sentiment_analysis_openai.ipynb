# %% [markdown]
# <a href="https://colab.research.google.com/github/somuvlsi01/python/blob/main/daily_news_sentiment_analysis_openai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.8/786.8 kB 16.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.99.1
#     Uninstalling openai-1.99.1:
#       Successfully uninstalled openai-1.99.1
# ...

# %%
from google.colab import userdata

OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')

# %%
from openai import OpenAI
client = OpenAI(
    api_key=OPENAI_API_KEY
)

# %%
response = client.responses.create(
    model="gpt-5-mini",
    tools=[{"type": "web_search_preview"}],
    input = "Search for the news that will impact the stock QQQ and GLD today and classify if the news is bullish or bearish for each of the stocks"
)

# %%
print(response.output_text)
# Out:
# I searched the market news for today (August 11, 2025) and pulled the key items likely to move QQQ (Invesco QQQ Trust / Nasdaq‑100 exposure) and GLD (SPDR Gold Shares / bullion exposure). Below are the main headlines, a one‑line summary of their market effect, and my classification (bullish / bearish / mixed) for QQQ and GLD with brief rationales and sources.
#
# 1) Report that Nvidia and AMD agreed to give ~15% of China AI‑chip revenue to the U.S. government in exchange for export licenses
# - What happened: multiple outlets report a deal/arrangement that would remit roughly 15% of advanced‑chip sales to China back to the U.S. government; Nvidia and AMD shares slipped in early trading on the report. ([investors.com](https://www.investors.com/news/technology/nvidia-amd-give-15-china-chip-revenue-u-s-government/?utm_source=chatgpt.com))
# ...
